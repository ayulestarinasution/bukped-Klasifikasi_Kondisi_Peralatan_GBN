# %%
#Library yang digunakan
import pandas as pd
import numpy as np

# %%
#import data dgn format excel
dataset = pd.read_excel('alat.xlsx')
#melihat data
dataset.head()
# Out:
#    JML       NAMA PERALATAN Jenis Alat     MEREK            TIPE    BUATAN  \
# 0    1          X-Ray Cabin      X-Ray  Rapiscan           620XR  Malaysia
# 1    2  X-Ray Bagasi Line 1      X-Ray     Smith  HS 100100T-2is  Malaysia
# 2    3  X-Ray Bagasi Line 2      X-Ray     Smith  HS 100100T-2is  Malaysia
# 3    4   X-Ray Cabin Line 1      X-Ray  Rapiscan           620DV  Malaysia
# 4    5   X-Ray Cabin Line 2      X-Ray  Rapiscan           620DV  Malaysia
#
#    TAHUN PEMBUATAN  KATEGORI KERUSAKAN  KONDISI (%)  Sertifikasi  Keterangan
# 0           2012.0                 3.0    53.333333             1      Rusak
# 1           2016.0                 4.0    80.000000             1     Normal
# 2           2016.0                 2.0    80.000000             1  Perbaikan
# 3           2017.0                 4.0    86.666667             1     Normal
# 4           2017.0                 4.0    86.666667             1     Normal
