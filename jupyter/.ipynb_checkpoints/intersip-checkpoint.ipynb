# %%
from flask import Flask, render_template, redirect, request, url_for, session
from flask_mysqldb import MySQL, MySQLdb
import bcrypt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import io
import random
from flask import Response
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from matplotlib.figure import Figure
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('alat.csv')

# %%
df.head(10)
# Out:
#    JML       NAMA_PERALATAN Jenis_Alat     MEREK              TIPE    BUATAN  \
# 0    1          X-Ray Cabin      X-Ray  Rapiscan             620XR  Malaysia
# 1    2  X-Ray Bagasi Line 1      X-Ray     Smith    HS 100100T-2is  Malaysia
# 2    3  X-Ray Bagasi Line 2      X-Ray     Smith    HS 100100T-2is  Malaysia
# 3    4   X-Ray Cabin Line 1      X-Ray  Rapiscan             620DV  Malaysia
# 4    5   X-Ray Cabin Line 2      X-Ray  Rapiscan             620DV  Malaysia
# 5    6   X-Ray Cabin Line 3      X-Ray  Rapiscan             620DV  Malaysia
# 6    7  X-Ray Bagasi Line 1      X-Ray  Rapiscan             628DV  Malaysia
# 7    8  X-Ray Bagasi Line 2      X-Ray     Smith    HS 100100T-2is  Malaysia
# 8    9   X-Ray Cabin Line 1      X-Ray     Smith  HI Scan 6040-2is  Malaysia
# 9   10   X-Ray Cabin Line 2      X-Ray     Smith  HI Scan 6040-2is  Malaysia
#
#    TAHUN_PEMBUATAN  KATEGORI_KERUSAKAN  KONDISI   Sertifikasi  Keterangan
# 0           2012.0                 3.0      53.0             1      Rusak
# 1           2016.0                 4.0      80.0             1     Normal
# 2           2016.0                 2.0      80.0             1  Perbaikan
# 3           2017.0                 4.0      87.0             1     Normal
# 4           2017.0                 4.0      87.0             1     Normal
# 5           2017.0                 2.0      87.0             1     Normal
# 6           2019.0                 1.0     100.0             2     Normal
# 7           2016.0                 2.0      80.0             1  Perbaikan
# 8           2016.0                 1.0      80.0             1  Perbaikan
# 9           2011.0                 3.0      47.0             1      Rusak

# %%
df.columns
# Out:
# Index(['JML', 'NAMA_PERALATAN', 'Jenis_Alat', 'MEREK', 'TIPE', 'BUATAN',
#        'TAHUN_PEMBUATAN', 'KATEGORI_KERUSAKAN', 'KONDISI ', 'Sertifikasi ',
#        'Keterangan'],
#       dtype='object')

# %%
df.shape
# Out:
# (596, 11)

# %%
df.describe()
# Out:
#               JML  TAHUN_PEMBUATAN  KATEGORI_KERUSAKAN    KONDISI   \
# count  596.000000       589.000000          402.000000  589.000000
# mean    46.505034      2016.258065            3.029851   76.139219
# std     41.280532         1.432598            1.091387   26.135915
# min      1.000000      1999.000000            1.000000    0.000000
# 25%     10.000000      2016.000000            2.000000   60.000000
# 50%     33.000000      2016.000000            3.000000   80.000000
# 75%     79.250000      2016.000000            4.000000  100.000000
# max    151.000000      2020.000000            4.000000  100.000000
#
#        Sertifikasi
# count    596.000000
# mean       1.003356
# std        0.057880
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        2.000000

# %%
df.loc[:, ['NAMA_PERALATAN', 'Jenis_Alat', 'MEREK', 'TIPE', 'BUATAN', 'TAHUN_PEMBUATAN','KATEGORI_KERUSAKAN', 'KONDISI ','Sertifikasi ','Keterangan']]
# Out:
#             NAMA_PERALATAN         Jenis_Alat     MEREK            TIPE  \
# 0              X-Ray Cabin              X-Ray  Rapiscan           620XR
# 1      X-Ray Bagasi Line 1              X-Ray     Smith  HS 100100T-2is
# 2      X-Ray Bagasi Line 2              X-Ray     Smith  HS 100100T-2is
# 3       X-Ray Cabin Line 1              X-Ray  Rapiscan           620DV
# 4       X-Ray Cabin Line 2              X-Ray  Rapiscan           620DV
# ..                     ...                ...       ...             ...
# 591  Smoke Detector FA-111  Fire Alarm System  Notifier         FSP-851
# 592  Smoke Detector FA-112  Fire Alarm System  Notifier         FSP-851
# 593  Smoke Detector FA-113  Fire Alarm System  Notifier         FSP-851
# 594  Smoke Detector FA-114  Fire Alarm System  Notifier         FSP-851
# 595  Smoke Detector FA-115  Fire Alarm System  Notifier         FSP-851
#
#        BUATAN  TAHUN_PEMBUATAN  KATEGORI_KERUSAKAN  KONDISI   Sertifikasi   \
# 0    Malaysia           2012.0                 3.0      53.0             1
# 1    Malaysia           2016.0                 4.0      80.0             1
# 2    Malaysia           2016.0                 2.0      80.0             1
# 3    Malaysia           2017.0                 4.0      87.0             1
# 4    Malaysia           2017.0                 4.0      87.0             1
# ..        ...              ...                 ...       ...           ...
# 591       USA           2016.0                 4.0     100.0             1
# 592       USA           2016.0                 4.0     100.0             1
# 593       USA           2016.0                 4.0     100.0             1
# 594       USA           2016.0                 4.0     100.0             1
# 595       USA           2016.0                 4.0     100.0             1
#
#     Keterangan
# 0        Rusak
# 1       Normal
# 2    Perbaikan
# 3       Normal
# 4       Normal
# ..         ...
# 591     Normal
# 592     Normal
# 593     Normal
# 594     Normal
# 595     Normal
#
# [596 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596 entries, 0 to 595
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   JML                 596 non-null    int64
#  1   NAMA_PERALATAN      596 non-null    object
#  2   Jenis_Alat          596 non-null    object
#  3   MEREK               590 non-null    object
#  4   TIPE                356 non-null    object
#  5   BUATAN              458 non-null    object
#  6   TAHUN_PEMBUATAN     589 non-null    float64
#  7   KATEGORI_KERUSAKAN  402 non-null    float64
#  8   KONDISI             589 non-null    float64
#  9   Sertifikasi         596 non-null    int64
#  10  Keterangan          596 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 51.3+ KB

# %%
df_features = df.drop('Keterangan', axis=1)
df_target = df['Keterangan']

# %%
df_features = df.drop('JML', axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596 entries, 0 to 595
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   JML                 596 non-null    int64
#  1   NAMA_PERALATAN      596 non-null    object
#  2   Jenis_Alat          596 non-null    object
#  3   MEREK               590 non-null    object
#  4   TIPE                356 non-null    object
#  5   BUATAN              458 non-null    object
#  6   TAHUN_PEMBUATAN     589 non-null    float64
#  7   KATEGORI_KERUSAKAN  402 non-null    float64
#  8   KONDISI             589 non-null    float64
#  9   Sertifikasi         596 non-null    int64
#  10  Keterangan          596 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 51.3+ KB

# %%
df_features
# Out:
#             NAMA_PERALATAN         Jenis_Alat     MEREK            TIPE  \
# 0              X-Ray Cabin              X-Ray  Rapiscan           620XR
# 1      X-Ray Bagasi Line 1              X-Ray     Smith  HS 100100T-2is
# 2      X-Ray Bagasi Line 2              X-Ray     Smith  HS 100100T-2is
# 3       X-Ray Cabin Line 1              X-Ray  Rapiscan           620DV
# 4       X-Ray Cabin Line 2              X-Ray  Rapiscan           620DV
# ..                     ...                ...       ...             ...
# 591  Smoke Detector FA-111  Fire Alarm System  Notifier         FSP-851
# 592  Smoke Detector FA-112  Fire Alarm System  Notifier         FSP-851
# 593  Smoke Detector FA-113  Fire Alarm System  Notifier         FSP-851
# 594  Smoke Detector FA-114  Fire Alarm System  Notifier         FSP-851
# 595  Smoke Detector FA-115  Fire Alarm System  Notifier         FSP-851
#
#        BUATAN  TAHUN_PEMBUATAN  KATEGORI_KERUSAKAN  KONDISI   Sertifikasi   \
# 0    Malaysia           2012.0                 3.0      53.0             1
# 1    Malaysia           2016.0                 4.0      80.0             1
# 2    Malaysia           2016.0                 2.0      80.0             1
# 3    Malaysia           2017.0                 4.0      87.0             1
# 4    Malaysia           2017.0                 4.0      87.0             1
# ..        ...              ...                 ...       ...           ...
# 591       USA           2016.0                 4.0     100.0             1
# 592       USA           2016.0                 4.0     100.0             1
# 593       USA           2016.0                 4.0     100.0             1
# 594       USA           2016.0                 4.0     100.0             1
# 595       USA           2016.0                 4.0     100.0             1
#
#     Keterangan
# 0        Rusak
# 1       Normal
# 2    Perbaikan
# 3       Normal
# 4       Normal
# ..         ...
# 591     Normal
# 592     Normal
# 593     Normal
# 594     Normal
# 595     Normal
#
# [596 rows x 10 columns]

# %%
cols = ['NAMA_PERALATAN', 'Jenis_Alat', 'MEREK', 'TIPE', 'BUATAN', 'TAHUN_PEMBUATAN','KATEGORI_KERUSAKAN', 'KONDISI ','Sertifikasi ','Keterangan']

df_features[cols] = df_features[cols].astype('category')

df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596 entries, 0 to 595
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NAMA_PERALATAN      596 non-null    category
#  1   Jenis_Alat          596 non-null    category
#  2   MEREK               590 non-null    category
#  3   TIPE                356 non-null    category
#  4   BUATAN              458 non-null    category
#  5   TAHUN_PEMBUATAN     589 non-null    category
#  6   KATEGORI_KERUSAKAN  402 non-null    category
#  7   KONDISI             589 non-null    category
#  8   Sertifikasi         596 non-null    category
#  9   Keterangan          596 non-null    category
# dtypes: category(10)
# memory usage: 32.0 KB

# %%
for col in cols:
        df_features[col] = df_features[col].cat.codes
        
df_features.head()
# Out:
#    NAMA_PERALATAN  Jenis_Alat  MEREK  TIPE  BUATAN  TAHUN_PEMBUATAN  \
# 0             584          16     15     4       7                2
# 1             582          16     19    15       7                6
# 2             583          16     19    15       7                6
# 3             585          16     15     3       7                7
# 4             586          16     15     3       7                7
#
#    KATEGORI_KERUSAKAN  KONDISI   Sertifikasi   Keterangan
# 0                   2         4             0           3
# 1                   3        10             0           1
# 2                   1        10             0           2
# 3                   3        12             0           1
# 4                   3        12             0           1

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler().fit_transform(df_features)

cols = list(df_features.columns)

df_features_scale = pd.DataFrame(scale, columns=cols)
df_features_scale.head()
# Out:
#    NAMA_PERALATAN  Jenis_Alat     MEREK      TIPE    BUATAN  TAHUN_PEMBUATAN  \
# 0        1.676249    1.662535 -0.135662 -0.450000  0.507388        -2.822536
# 1        1.664571    1.662535  0.423885  0.495880  0.507388        -0.128811
# 2        1.670410    1.662535  0.423885  0.495880  0.507388        -0.128811
# 3        1.682088    1.662535 -0.135662 -0.535989  0.507388         0.544621
# 4        1.687927    1.662535 -0.135662 -0.535989  0.507388         0.544621
#
#    KATEGORI_KERUSAKAN  KONDISI   Sertifikasi   Keterangan
# 0            0.569828 -1.043513     -0.058026    2.786150
# 1            1.165648  0.072731     -0.058026   -0.457103
# 2           -0.025992  0.072731     -0.058026    1.164523
# 3            1.165648  0.444812     -0.058026   -0.457103
# 4            1.165648  0.444812     -0.058026   -0.457103

# %%
X_train, X_test, y_train, y_test = train_test_split(df_features_scale, df_target, test_size=0.2, random_state=42)

print('Train set :', X_train.shape, y_train.shape)
print('Test set :', X_test.shape, y_test.shape)
# Out:
# Train set : (476, 10) (476,)
# Test set : (120, 10) (120,)

# %%
#Membuat model naive bayes terhadap training test
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#prediksi hasil test set
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array(['Perbaikan', 'Rusak', 'Normal', 'Normal', 'Normal', 'Perbaikan',
#        'Rusak', 'Normal', 'Perbaikan', 'Normal', 'Normal', 'Normal',
#        'Perbaikan', 'Normal', 'Normal', 'Perbaikan', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Rusak',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Rusak', 'Normal',
#        'Normal', 'Normal', 'Perbaikan', 'Rusak', 'Normal', 'Normal',
#        'Perbaikan', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Perbaikan',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Perbaikan', 'Normal',
#        'Normal', 'Normal', 'Rusak', 'Perbaikan', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Perbaikan', 'Rusak',
#        'Normal', 'Normal', 'Normal', 'Rusak', 'Normal', 'Normal',
#        'Perbaikan', 'Normal', 'Normal', 'Normal', 'Perbaikan', 'Normal',
#        'Normal', 'Rusak', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Perbaikan', 'Normal', 'Normal', 'Rusak', 'Normal',
#        'Normal', 'Rusak', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Perbaikan', 'Normal', 'Normal', 'Rusak', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal'],
#       dtype='<U9')

# %%
print(y_pred[0:5])
print(y_test[0:5])
# Out:
# ['Perbaikan' 'Rusak' 'Normal' 'Normal' 'Normal']
# 188    Perbaikan
# 238        Rusak
# 462       Normal
# 465       Normal
# 182       Normal
# Name: Keterangan, dtype: object

# %%
#menghitung akurasi
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
#confusion matriks
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[93,  0,  0],
#        [ 0, 15,  0],
#        [ 0,  0, 12]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="Keterangan")
plt.title("Kondisi Peralatan", fontsize=20)
plt.show()

# %%
plt.scatter(df['Keterangan'],df['KONDISI '])
